# %% [markdown]
# # File scanner

# %%
import pandas as pd

import os
import datetime
import pprint

# %%
directory = r'/Users/peter/Computrain/_InCompany/Defensie/Python Traject'

# %%
for root, dirs, files in os.walk(directory, followlinks=False):

    dirs[:] = [d for d in dirs if not d.startswith('.') and not d.startswith('__')] 
    files[:] = [f for f in files if not f.startswith('.')] 

    # print('>>>>>>', root)
    # print(dirs)
    # print(files)
    # print(80 * '-')

    entries = []
    for file in files:
        filepath = os.path.join(root, file)

        size = os.path.getsize(filepath)

        stat = os.stat(filepath)

        atime = datetime.datetime.fromtimestamp(stat.st_atime)
        mtime = datetime.datetime.fromtimestamp(stat.st_mtime)
        ctime = datetime.datetime.fromtimestamp(stat.st_ctime)

        d = {
            'dir': root,
            'file': file,
            'size': size,
            'atime': atime,
            'mtime': mtime,
            'ctime': ctime,
        }
        entries.append(d)

pprint.pprint(entries)
# Out:
# [{'atime': datetime.datetime(2025, 9, 30, 10, 46, 35, 982085),
#   'ctime': datetime.datetime(2025, 9, 30, 10, 45, 49, 260517),
#   'dir': '/Users/peter/Computrain/_InCompany/Defensie/Python '
#          'Traject/Cursus/Dag 2',
#   'file': 'demo_flow.py',
#   'mtime': datetime.datetime(2025, 9, 30, 10, 45, 49, 260517),
#   'size': 414},
#  {'atime': datetime.datetime(2025, 9, 30, 14, 58, 1, 964807),
#   'ctime': datetime.datetime(2025, 9, 30, 14, 58, 0, 647111),
#   'dir': '/Users/peter/Computrain/_InCompany/Defensie/Python '
#          'Traject/Cursus/Dag 2',
#   'file': 'new_password.py',
#   'mtime': datetime.datetime(2025, 9, 30, 14, 58, 0, 647111),
#   'size': 624},
#  {'atime': datetime.datetime(2025, 9, 30, 15, 57, 40, 563771),
#   'ctime': datetime.datetime(2025, 9, 30, 15, 57, 38, 682246),
#   'dir': '/Users/peter/Computrain/_InCompany/Defensie/Python '
#          'Traject/Cursus/Dag 2',
#   'file': 'hangman.py',
#   'mtime': datetime.datetime(2025, 9, 30, 15, 57, 38, 682246),
#   'size': 203},
#  {'atime': datetime.datetime(2025, 10, 1, 9, 0, 15, 422198),
#   'ctime': datetime.datetime(2025, 9, 30, 15, 46, 59, 441973),
#   'dir': '/Users/peter/Computrain/_InCompany/Defensie/Python '
#          'Traject/Cursus/Dag 2',
#   'file': 'basiswoorden-gekeurd.txt',
#   'mtime': datetime.datetime(2025, 9, 30, 15, 46, 22, 28807),
#   'size': 2532852},
#  {'atime': datetime.datetime(2025, 9, 30, 15, 22, 35, 28180),
#   'ctime': datetime.datetime(2025, 9, 30, 15, 22, 33, 776663),
#   'dir': '/Users/peter/Computrain/_InCompany/Defensie/Python '
#          'Traject/Cursus/Dag 2',
#   'file': 'timeit_in.py',
#   'mtime': datetime.datetime(2023, 12, 12, 13, 25, 43, 172586),
#   'size': 761},
#  {'atime': datetime.datetime(2025, 9, 30, 13, 1, 44, 404823),
#   'ctime': datetime.datetime(2025, 9, 30, 13, 1, 42, 291319),
#   'dir': '/Users/peter/Computrain/_InCompany/Defensie/Python '
#          'Traject/Cursus/Dag 2',
#   'file': 'guessing-game-player.py',
#   'mtime': datetime.datetime(2025, 9, 30, 13, 1, 42, 291319),
#   'size': 666},
#  {'atime': datetime.datetime(2025, 9, 30, 9, 49, 35, 892557),
#   'ctime': datetime.datetime(2025, 9, 30, 9, 48, 55, 47549),
#   'dir': '/Users/peter/Computrain/_InCompany/Defensie/Python '
#          'Traject/Cursus/Dag 2',
#   'file': 'recap.py',
#   'mtime': datetime.datetime(2025, 9, 30, 9, 48, 55, 47549),
#   'size': 599}]

# %%
df = pd.DataFrame(entries)
df
# Out:
#                                                  dir  \
# 0  /Users/peter/Computrain/_InCompany/Defensie/Py...
# 1  /Users/peter/Computrain/_InCompany/Defensie/Py...
# 2  /Users/peter/Computrain/_InCompany/Defensie/Py...
# 3  /Users/peter/Computrain/_InCompany/Defensie/Py...
# 4  /Users/peter/Computrain/_InCompany/Defensie/Py...
# 5  /Users/peter/Computrain/_InCompany/Defensie/Py...
# 6  /Users/peter/Computrain/_InCompany/Defensie/Py...
#
#                        file     size                      atime  \
# 0              demo_flow.py      414 2025-09-30 10:46:35.982085
# 1           new_password.py      624 2025-09-30 14:58:01.964807
# 2                hangman.py      203 2025-09-30 15:57:40.563771
# 3  basiswoorden-gekeurd.txt  2532852 2025-10-01 09:00:15.422198
# 4              timeit_in.py      761 2025-09-30 15:22:35.028180
# 5   guessing-game-player.py      666 2025-09-30 13:01:44.404823
# 6                  recap.py      599 2025-09-30 09:49:35.892557
#
#                        mtime                      ctime
# 0 2025-09-30 10:45:49.260517 2025-09-30 10:45:49.260517
# 1 2025-09-30 14:58:00.647111 2025-09-30 14:58:00.647111
# 2 2025-09-30 15:57:38.682246 2025-09-30 15:57:38.682246
# 3 2025-09-30 15:46:22.028807 2025-09-30 15:46:59.441973
# 4 2023-12-12 13:25:43.172586 2025-09-30 15:22:33.776663
# 5 2025-09-30 13:01:42.291319 2025-09-30 13:01:42.291319
# 6 2025-09-30 09:48:55.047549 2025-09-30 09:48:55.047549
