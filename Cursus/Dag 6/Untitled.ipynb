# %% [markdown]
# # Read csv file

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Get the data

# %%
filename = 'ca-500.csv'

# %%
df = pd.read_csv(filename)

# %% [markdown]
# ### EDA - Exploratory Data Anaysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   first_name     500 non-null    object
#  1   last_name      500 non-null    object
#  2   company_name   500 non-null    object
#  3   address        500 non-null    object
#  4   city           500 non-null    object
#  5   province       500 non-null    object
#  6   postal         500 non-null    object
#  7   phone1         500 non-null    object
#  8   phone2         500 non-null    object
#  9   email          490 non-null    object
#  10  web            500 non-null    object
#  11  date_of_birth  500 non-null    object
# dtypes: object(12)
# memory usage: 47.0+ KB

# %%
df
# Out:
#     first_name   last_name                    company_name  \
# 0    Francoise     Kohlman               Riebesell, H F Jr
# 1       Kendra      Yandow               Deloitte & Touche
# 2      Lourdes     Beliles               Oklahoma Neon Inc
# 3       Hannah    Helmcamp              M B A Paint Stores
# 4          Tom       Sport       Sheraton Shreveport Hotel
# ..         ...         ...                             ...
# 495       Erin       Lafoy             Curtiss Wright Corp
# 496  Kassandra     Batdorf        Phelps Tool & Die Co Inc
# 497     Leslee  Bredernitz         Factory Mattress Outlet
# 498     Daniel      Cisney  Cosgroves N End Plbg & Hdwr Co
# 499    Antonio       Fower      Mission Lincoln Properties
#
#                     address            city province   postal        phone1  \
# 0        2335 Canton Hwy #6         Windsor       ON  N8N 3N2  519-569-8399
# 1           6 Arch St #9757          Alcida       NB  E8J 2C4  506-363-1526
# ...

# %%
df[['city', 'province']]
# Out:
#                city province
# 0           Windsor       ON
# 1            Alcida       NB
# 2        Belleville       ON
# 3         Vancouver       BC
# 4       LIle-Perrot       QC
# ..              ...      ...
# 495       Longueuil       QC
# 496         Nanaimo       BC
# 497          Quebec       QC
# 498       Beresford       NB
# 499  Port Coquitlam       BC
#
# [500 rows x 2 columns]

# %%
df['province'].value_counts()
# Out:
# province
# ON    175
# QC    116
# BC     72
# AB     42
# NB     30
# NS     23
# SK     21
# MB     12
# NL      8
# PE      1
# Name: count, dtype: int64

# %%
df['province'].value_counts().plot(kind='barh');

# %%
df['province'].value_counts().plot(kind='pie');

# %%
# df['name'] = df['first_name'] + ' ' + df['last_name']

df.insert(2, 'name', df['first_name'] + ' ' + df['last_name'])

# %%
df[['first_name', 'last_name', 'name', 'city']]
# Out:
#     first_name   last_name               name            city
# 0    Francoise     Kohlman  Francoise Kohlman         Windsor
# 1       Kendra      Yandow      Kendra Yandow          Alcida
# 2      Lourdes     Beliles    Lourdes Beliles      Belleville
# 3       Hannah    Helmcamp    Hannah Helmcamp       Vancouver
# 4          Tom       Sport          Tom Sport     LIle-Perrot
# ..         ...         ...                ...             ...
# 495       Erin       Lafoy         Erin Lafoy       Longueuil
# 496  Kassandra     Batdorf  Kassandra Batdorf         Nanaimo
# 497     Leslee  Bredernitz  Leslee Bredernitz          Quebec
# 498     Daniel      Cisney      Daniel Cisney       Beresford
# 499    Antonio       Fower      Antonio Fower  Port Coquitlam
#
# [500 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   first_name     500 non-null    object
#  1   last_name      500 non-null    object
#  2   name           500 non-null    object
#  3   company_name   500 non-null    object
#  4   address        500 non-null    object
#  5   city           500 non-null    object
#  6   province       500 non-null    object
#  7   postal         500 non-null    object
#  8   phone1         500 non-null    object
#  9   phone2         500 non-null    object
#  10  email          490 non-null    object
#  11  web            500 non-null    object
#  12  date_of_birth  500 non-null    object
# dtypes: object(13)
# memory usage: 50.9+ KB

# %%
df.head(3)
# Out:
#   first_name last_name               name       company_name  \
# 0  Francoise   Kohlman  Francoise Kohlman  Riebesell, H F Jr
# 1     Kendra    Yandow      Kendra Yandow  Deloitte & Touche
# 2    Lourdes   Beliles    Lourdes Beliles  Oklahoma Neon Inc
#
#                address        city province   postal        phone1  \
# 0   2335 Canton Hwy #6     Windsor       ON  N8N 3N2  519-569-8399
# 1      6 Arch St #9757      Alcida       NB  E8J 2C4  506-363-1526
# 2  9547 Belmont Rd #21  Belleville       ON  K8P 1B3  613-903-7043
#
#          phone2                  email                             web  \
# 0  519-978-6179  f.kohlman@hotmail.com    http://www.riebesellhfjr.com
# 1  506-932-4472        kendray@cox.net   http://www.deloittetouche.com
# 2  613-638-6682    l.beliles@gmail.com  http://www.oklahomaneoninc.com
#
#   date_of_birth
# 0    1970-11-05
# 1    1960-02-17
# 2    2001-12-18

# %% [markdown]
# ### SQL SELECT

# %%
df[ ['first_name','last_name','name', 'city'] ]
# Out:
#     first_name   last_name               name            city
# 0    Francoise     Kohlman  Francoise Kohlman         Windsor
# 1       Kendra      Yandow      Kendra Yandow          Alcida
# 2      Lourdes     Beliles    Lourdes Beliles      Belleville
# 3       Hannah    Helmcamp    Hannah Helmcamp       Vancouver
# 4          Tom       Sport          Tom Sport     LIle-Perrot
# ..         ...         ...                ...             ...
# 495       Erin       Lafoy         Erin Lafoy       Longueuil
# 496  Kassandra     Batdorf  Kassandra Batdorf         Nanaimo
# 497     Leslee  Bredernitz  Leslee Bredernitz          Quebec
# 498     Daniel      Cisney      Daniel Cisney       Beresford
# 499    Antonio       Fower      Antonio Fower  Port Coquitlam
#
# [500 rows x 4 columns]

# %% [markdown]
# ### SQL SELECT & WHERE

# %%
df[['first_name','last_name','name', 'city']].query('city=="Vancouver"')

# df.loc[df['city'] == "Vancouver", ['first_name','last_name','name', 'city']]
# Out:
#     first_name last_name             name       city
# 3       Hannah  Helmcamp  Hannah Helmcamp  Vancouver
# 69       Janna     Peets      Janna Peets  Vancouver
# 108     Kaycee   Rubarts   Kaycee Rubarts  Vancouver
# 115      Luisa  Hofbauer   Luisa Hofbauer  Vancouver
# 128      Mindy    Meisel     Mindy Meisel  Vancouver
# 140   Jannette    Kylish  Jannette Kylish  Vancouver
# 218    Brandon    Stalma   Brandon Stalma  Vancouver
# 225    Bettina   Perkins  Bettina Perkins  Vancouver
# 408    Maynard   Metzner  Maynard Metzner  Vancouver

# %% [markdown]
# ### SQL SELECT & WHERE & ORDER BY

# %%
df[['first_name','last_name','name', 'city']].query('city=="Vancouver"').sort_values('last_name')
# Out:
#     first_name last_name             name       city
# 3       Hannah  Helmcamp  Hannah Helmcamp  Vancouver
# 115      Luisa  Hofbauer   Luisa Hofbauer  Vancouver
# 140   Jannette    Kylish  Jannette Kylish  Vancouver
# 128      Mindy    Meisel     Mindy Meisel  Vancouver
# 408    Maynard   Metzner  Maynard Metzner  Vancouver
# 69       Janna     Peets      Janna Peets  Vancouver
# 225    Bettina   Perkins  Bettina Perkins  Vancouver
# 108     Kaycee   Rubarts   Kaycee Rubarts  Vancouver
# 218    Brandon    Stalma   Brandon Stalma  Vancouver

# %% [markdown]
# ### SQL GROUP BY

# %%
df.groupby('province').agg(func='size')
# Out:
# province
# AB     42
# BC     72
# MB     12
# NB     30
# NL      8
# NS     23
# ON    175
# PE      1
# QC    116
# SK     21
# dtype: int64

# %%
df['province'].value_counts()
# Out:
# province
# ON    175
# QC    116
# BC     72
# AB     42
# NB     30
# NS     23
# SK     21
# MB     12
# NL      8
# PE      1
# Name: count, dtype: int64

# %% [markdown]
# ### Dates

# %%
df['date_of_birth']
# Out:
# 0      1970-11-05
# 1      1960-02-17
# 2      2001-12-18
# 3      1955-09-20
# 4      1952-08-20
#           ...
# 495    1975-11-29
# 496    1957-12-09
# 497    1976-07-06
# 498    1961-12-08
# 499    1991-08-01
# Name: date_of_birth, Length: 500, dtype: object

# %%
df['date_of_birth'] = pd.to_datetime(df['date_of_birth'], format='%Y-%m-%d')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   first_name     500 non-null    object
#  1   last_name      500 non-null    object
#  2   name           500 non-null    object
#  3   company_name   500 non-null    object
#  4   address        500 non-null    object
#  5   city           500 non-null    object
#  6   province       500 non-null    object
#  7   postal         500 non-null    object
#  8   phone1         500 non-null    object
#  9   phone2         500 non-null    object
#  10  email          490 non-null    object
#  11  web            500 non-null    object
#  12  date_of_birth  500 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(12)
# memory usage: 50.9+ KB

# %%
df['year_of_birth'] = df['date_of_birth'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   first_name     500 non-null    object
#  1   last_name      500 non-null    object
#  2   name           500 non-null    object
#  3   company_name   500 non-null    object
#  4   address        500 non-null    object
#  5   city           500 non-null    object
#  6   province       500 non-null    object
#  7   postal         500 non-null    object
#  8   phone1         500 non-null    object
#  9   phone2         500 non-null    object
#  10  email          490 non-null    object
#  11  web            500 non-null    object
#  12  date_of_birth  500 non-null    datetime64[ns]
#  13  year_of_birth  500 non-null    int32
# dtypes: datetime64[ns](1), int32(1), object(12)
# memory usage: 52.9+ KB

# %%
df
# Out:
#     first_name   last_name               name                    company_name  \
# 0    Francoise     Kohlman  Francoise Kohlman               Riebesell, H F Jr
# 1       Kendra      Yandow      Kendra Yandow               Deloitte & Touche
# 2      Lourdes     Beliles    Lourdes Beliles               Oklahoma Neon Inc
# 3       Hannah    Helmcamp    Hannah Helmcamp              M B A Paint Stores
# 4          Tom       Sport          Tom Sport       Sheraton Shreveport Hotel
# ..         ...         ...                ...                             ...
# 495       Erin       Lafoy         Erin Lafoy             Curtiss Wright Corp
# 496  Kassandra     Batdorf  Kassandra Batdorf        Phelps Tool & Die Co Inc
# 497     Leslee  Bredernitz  Leslee Bredernitz         Factory Mattress Outlet
# 498     Daniel      Cisney      Daniel Cisney  Cosgroves N End Plbg & Hdwr Co
# 499    Antonio       Fower      Antonio Fower      Mission Lincoln Properties
#
# ...

# %%
df['year_of_birth'].hist(bins=np.arange(1950, 2002))
# Out:
# <Axes: >

# %%
df['year_of_birth'].value_counts().sort_index()
# Out:
# year_of_birth
# 1950     8
# 1951    11
# 1952     7
# 1953    13
# 1954    15
# 1955    10
# 1956     9
# 1957    12
# 1958     9
# 1959     8
# 1960    10
# 1961    14
# 1962     5
# 1963    12
# 1964    12
# 1965     9
# 1966     8
# 1967    11
# 1968     5
# 1969    16
# 1970    10
# 1971    14
# 1972     7
# 1973     9
# 1974    13
# 1975     8
# 1976    14
# 1977     8
# 1978    12
# 1979     7
# 1980    11
# 1981     9
# 1982    12
# 1983    11
# 1984    11
# 1985     7
# 1986    10
# 1987    11
# 1988     7
# 1989     6
# 1990    10
# 1991    11
# 1992     7
# 1993     9
# 1994     7
# 1995     9
# 1996     7
# 1997     4
# 1998     3
# 1999     9
# 2000    14
# 2001     9
# Name: count, dtype: int64
